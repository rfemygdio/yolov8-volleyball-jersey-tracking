# %% [markdown]
# # YOLOv8 Volleyball Jersey Tracking Workflow
# This notebook demonstrates environment setup, dataset preparation, training, and inference for the jersey-tracking project.

# %%
# !pip install -r ../requirements.txt

# %%
from config import CONFIG
CONFIG

# %%
# !python -m scripts.data_preparation --bootstrap-only

# %%
# Replace yolov8n.pt with a fine-tuned checkpoint when ready
# !python -m scripts.train --data data/dataset.yaml --model yolov8n.pt --epochs 50

# %%
# !python -m scripts.inference --source 0 --model ../models/best.pt --display
